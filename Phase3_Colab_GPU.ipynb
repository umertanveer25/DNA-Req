# %% [markdown]
# # DNA-NFR Phase 3 (Domain Adapted SBERT) on Google Colab
#
# Evaluates Phase 3. Requires a GPU to fine-tune the neural network models.

# %%
# !git clone -b bio-optimizers https://github.com/umertanveer25/DNA-Req.git
# %cd DNA-Req
# !pip install -r requirements.txt
# !pip install sentence-transformers joblib pandas scikit-learn numpy

# %%
# !python reproduce_phase3_leakfree.py
