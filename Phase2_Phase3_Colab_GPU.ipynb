# %% [markdown]
# # DNA-NFR Phase 2 & Phase 3 (Leak-Free) on Google Colab GPU
#
# This notebook evaluates the mathematically rigorous, leak-free pipeline across 300 Cross-Validation folds.

# %%
# !git clone -b bio-optimizers https://github.com/umertanveer25/DNA-Req.git
# %cd DNA-Req
# !pip install -r requirements.txt
# !pip install sentence-transformers joblib pandas scikit-learn numpy

# %% [markdown]
# ## Run Phase 2 (Canonical DNA + Frozen SBERT)
# This runs extremely fast because SBERT is pre-computed (which is mathematically valid since it is unsupervised).

# %%
# !python reproduce_phase2_sbert.py
